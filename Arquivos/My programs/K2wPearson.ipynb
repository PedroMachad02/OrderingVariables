# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import K2Score, BayesianEstimator

def correlacao_pearson(data, target):
    # Calcula a correlação de Pearson entre a coluna alvo e todas as outras colunas
    correlacoes = data.corr(method='pearson')[target]
    
    # Ordena as colunas com base na correlação em ordem decrescente
    correlacoes_ordenadas = correlacoes.abs().sort_values(ascending=False)
    
    # Reordena o DataFrame de acordo com as correlações ordenadas
    colunas_ordenadas = correlacoes_ordenadas.index
    df_ordenado = data[colunas_ordenadas]
    
    return df_ordenado

def k2(dataset, parents_nmax):
    estimator = K2Score(dataset)
    model = BayesianNetwork()
    nodes = list(dataset.columns)
    model.add_nodes_from(nodes)

    for i in range(1, len(nodes)):
        node = nodes[i]
        previous_nodes = nodes[:i]
        parents = []
        P_old = estimator.local_score(node, parents)
        proceed = True

        while proceed and (len(parents) < parents_nmax):
            candidates = list(set(previous_nodes) - set(parents))
            P_new = P_old

            for candidate in candidates:
                candidate_score = estimator.local_score(node, parents + [candidate])

                if candidate_score > P_new:
                    candidates_best = candidate
                    P_new = candidate_score

            if P_new > P_old:
                P_old = P_new
                parents.append(candidates_best)
                model.add_edge(candidates_best, node)
            else:
                proceed = False

    estrutura = list(model.edges)
    score = estimator.score(model)
    return estrutura, model, score

def tabular_cpd(model, data):
    for column in data.columns:
        data[column] = pd.Categorical(data[column])
    estimator = BayesianEstimator(model, data)
    cpds = [estimator.estimate_cpd(node) for node in model.nodes]
    return cpds

# Variáveis para acompanhar a melhor estrutura, melhor ordem, melhor score e a target_column relacionada
melhor_estrutura = None
melhor_ordem = None
melhor_score = float('-inf')
melhor_target = None

data = pd.read_csv('sachs.csv') #Caminho do dataset
# Mapear os valores nominais para números inteiros únicos
data = data.apply(LabelEncoder().fit_transform)
variables = list(data.columns)

print("DataFrame original:")
print(list(data))

for target in variables:
    if target == 'target':
        continue
    # Ordena o DataFrame por correlação
    df_ordenado = correlacao_pearson(data, target)
    variable_target = list(df_ordenado)
    estrutura, model, score = k2(df_ordenado, 4)
    print(f'Ordem gerada com a feature ({target}): {variable_target}')
    print(f'Estrutura gerada: {estrutura}')
    print(f'Score obtido: {score}')

    # Verificar se esta estrutura é a melhor até agora
    if score > melhor_score:
        melhor_estrutura = estrutura
        melhor_ordem = list(df_ordenado)
        melhor_score = score
        melhor_target = target
        melhor_model = model

# Tabular as CPDs para o melhor modelo gerado
cpds = tabular_cpd(melhor_model, df_ordenado)

# Abre o arquivo em modo de escrita
with open("sachs_pearson.txt", "w") as arquivo:
    # Escreve os prints no arquivo
    arquivo.write(f'Melhor ordem gerada com a feature ({melhor_target}): {melhor_ordem}\n')
    arquivo.write(f'Estrutura dessa ordem: {melhor_estrutura}\n')
    arquivo.write(f'Score obtido dessa ordem: {melhor_score}\n')
# Out:
# DataFrame original:
# ['Akt', 'Erk', 'Jnk', 'Mek', 'P38', 'PIP2', 'PIP3', 'PKA', 'PKC', 'Plcg', 'Raf']
# Ordem gerada com a feature (Akt): ['Akt', 'Erk', 'Mek', 'PKA', 'Raf', 'P38', 'Jnk', 'PKC', 'PIP3', 'PIP2', 'Plcg']
# Estrutura gerada: [('Akt', 'Erk'), ('Akt', 'Mek'), ('Akt', 'PKA'), ('Erk', 'Mek'), ('Erk', 'PKA'), ('Mek', 'PKA'), ('Mek', 'Raf'), ('Mek', 'P38'), ('Mek', 'Jnk'), ('Mek', 'PKC'), ('PKA', 'Raf'), ('PKA', 'P38'), ('PKA', 'Jnk'), ('PKA', 'PKC'), ('Raf', 'PKC'), ('P38', 'Jnk'), ('Jnk', 'PKC'), ('PIP3', 'PIP2'), ('PIP3', 'Plcg'), ('PIP2', 'Plcg')]
# Score obtido: -72718.78759962883
# Ordem gerada com a feature (Erk): ['Erk', 'Akt', 'Mek', 'Raf', 'PKC', 'PKA', 'P38', 'Jnk', 'PIP2', 'Plcg', 'PIP3']
# Estrutura gerada: [('Erk', 'Akt'), ('Erk', 'Mek'), ('Erk', 'Raf'), ('Erk', 'PKA'), ('Akt', 'Mek'), ('Akt', 'PKC'), ('Mek', 'Raf'), ('Mek', 'PKC'), ('Mek', 'PKA'), ('Raf', 'PKC'), ('Raf', 'PKA'), ('PKC', 'PKA'), ('PKC', 'P38'), ('PKC', 'Jnk'), ('PKA', 'P38'), ('PKA', 'Jnk'), ('PIP2', 'Plcg'), ('PIP2', 'PIP3'), ('Plcg', 'PIP3')]
# Score obtido: -72738.28925485065
# Ordem gerada com a feature (Jnk): ['Jnk', 'PKA', 'P38', 'Mek', 'Raf', 'Akt', 'PKC', 'Erk', 'PIP2', 'PIP3', 'Plcg']
# Estrutura gerada: [('Jnk', 'PKA'), ('Jnk', 'P38'), ('Jnk', 'Mek'), ('Jnk', 'PKC'), ('PKA', 'P38'), ('PKA', 'Mek'), ('PKA', 'Raf'), ('PKA', 'Akt'), ('PKA', 'PKC'), ('PKA', 'Erk'), ('P38', 'Mek'), ('Mek', 'Raf'), ('Mek', 'Akt'), ('Mek', 'PKC'), ('Mek', 'Erk'), ('Raf', 'PKC'), ('Akt', 'Erk'), ('PIP2', 'PIP3'), ('PIP2', 'Plcg'), ('PIP3', 'Plcg')]
# Score obtido: -72705.46712860093
# Ordem gerada com a feature (Mek): ['Mek', 'Raf', 'Akt', 'PKA', 'Erk', 'P38', 'Jnk', 'PKC', 'PIP3', 'Plcg', 'PIP2']
# Estrutura gerada: [('Mek', 'Raf'), ('Mek', 'Akt'), ('Mek', 'PKA'), ('Mek', 'Erk'), ('Mek', 'P38'), ('Mek', 'Jnk'), ('Mek', 'PKC'), ('Raf', 'PKA'), ('Raf', 'PKC'), ('Akt', 'PKA'), ('Akt', 'Erk'), ('PKA', 'Erk'), ('PKA', 'P38'), ('PKA', 'Jnk'), ('PKA', 'PKC'), ('P38', 'Jnk'), ('Jnk', 'PKC'), ('PIP3', 'Plcg'), ('PIP3', 'PIP2'), ('Plcg', 'PIP2')]
# Score obtido: -72765.04735004123
# Ordem gerada com a feature (P38): ['P38', 'PKA', 'Raf', 'Akt', 'Mek', 'Jnk', 'PKC', 'Erk', 'PIP3', 'PIP2', 'Plcg']
# Estrutura gerada: [('P38', 'PKA'), ('P38', 'Raf'), ('P38', 'Jnk'), ('PKA', 'Raf'), ('PKA', 'Akt'), ('PKA', 'Mek'), ('PKA', 'Jnk'), ('PKA', 'PKC'), ('PKA', 'Erk'), ('Raf', 'Akt'), ('Raf', 'Mek'), ('Raf', 'PKC'), ('Akt', 'Mek'), ('Akt', 'Erk'), ('Mek', 'Jnk'), ('Mek', 'PKC'), ('Mek', 'Erk'), ('Jnk', 'PKC'), ('PIP3', 'PIP2'), ('PIP3', 'Plcg'), ('PIP2', 'Plcg')]
# Score obtido: -72808.950802048
# Ordem gerada com a feature (PIP2): ['PIP2', 'Plcg', 'PIP3', 'Jnk', 'Erk', 'PKA', 'PKC', 'Akt', 'P38', 'Mek', 'Raf']
# Estrutura gerada: [('PIP2', 'Plcg'), ('PIP2', 'PIP3'), ('Plcg', 'PIP3'), ('Jnk', 'Erk'), ('Jnk', 'PKA'), ('Jnk', 'PKC'), ('Erk', 'PKA'), ('Erk', 'PKC'), ('Erk', 'Akt'), ('Erk', 'Mek'), ('PKA', 'PKC'), ('PKA', 'Akt'), ('PKA', 'P38'), ('PKA', 'Mek'), ('PKA', 'Raf'), ('PKC', 'P38'), ('PKC', 'Mek'), ('PKC', 'Raf'), ('Mek', 'Raf')]
# Score obtido: -72352.3487885249
# Ordem gerada com a feature (PIP3): ['PIP3', 'Plcg', 'PIP2', 'Akt', 'P38', 'Mek', 'Jnk', 'PKA', 'Raf', 'Erk', 'PKC']
# Estrutura gerada: [('PIP3', 'Plcg'), ('PIP3', 'PIP2'), ('Plcg', 'PIP2'), ('Akt', 'P38'), ('Akt', 'Mek'), ('Akt', 'PKA'), ('Akt', 'Erk'), ('P38', 'Mek'), ('P38', 'Jnk'), ('P38', 'PKA'), ('Mek', 'Jnk'), ('Mek', 'PKA'), ('Mek', 'Raf'), ('Mek', 'Erk'), ('Mek', 'PKC'), ('Jnk', 'PKA'), ('Jnk', 'PKC'), ('PKA', 'Raf'), ('PKA', 'Erk'), ('PKA', 'PKC'), ('Raf', 'PKC')]
# Score obtido: -72926.80102679272
# Ordem gerada com a feature (PKA): ['PKA', 'Raf', 'Mek', 'Jnk', 'P38', 'Akt', 'PKC', 'Erk', 'PIP2', 'PIP3', 'Plcg']
# Estrutura gerada: [('PKA', 'Raf'), ('PKA', 'Mek'), ('PKA', 'Jnk'), ('PKA', 'P38'), ('PKA', 'Akt'), ('PKA', 'PKC'), ('PKA', 'Erk'), ('Raf', 'Mek'), ('Raf', 'PKC'), ('Mek', 'Jnk'), ('Mek', 'P38'), ('Mek', 'Akt'), ('Mek', 'PKC'), ('Mek', 'Erk'), ('Jnk', 'P38'), ('Jnk', 'PKC'), ('Akt', 'Erk'), ('PIP2', 'PIP3'), ('PIP2', 'Plcg'), ('PIP3', 'Plcg')]
# Score obtido: -72712.99695773
# Ordem gerada com a feature (PKC): ['PKC', 'Raf', 'P38', 'Akt', 'Mek', 'PKA', 'Erk', 'Jnk', 'PIP2', 'Plcg', 'PIP3']
# Estrutura gerada: [('PKC', 'Raf'), ('PKC', 'P38'), ('PKC', 'Akt'), ('PKC', 'Mek'), ('PKC', 'PKA'), ('PKC', 'Jnk'), ('Raf', 'P38'), ('Raf', 'Akt'), ('Raf', 'Mek'), ('Raf', 'PKA'), ('P38', 'Akt'), ('P38', 'PKA'), ('Akt', 'Mek'), ('Akt', 'Erk'), ('Mek', 'PKA'), ('Mek', 'Erk'), ('PKA', 'Erk'), ('PKA', 'Jnk'), ('PIP2', 'Plcg'), ('PIP2', 'PIP3'), ('Plcg', 'PIP3')]
# Score obtido: -72675.03150376589
# Ordem gerada com a feature (Plcg): ['Plcg', 'PIP2', 'PIP3', 'Erk', 'Jnk', 'Raf', 'PKC', 'PKA', 'P38', 'Mek', 'Akt']
# Estrutura gerada: [('Plcg', 'PIP2'), ('Plcg', 'PIP3'), ('PIP2', 'PIP3'), ('Erk', 'Jnk'), ('Erk', 'Raf'), ('Erk', 'PKA'), ('Erk', 'Mek'), ('Erk', 'Akt'), ('Jnk', 'Raf'), ('Jnk', 'PKC'), ('Jnk', 'PKA'), ('Raf', 'PKC'), ('Raf', 'PKA'), ('Raf', 'Mek'), ('PKC', 'PKA'), ('PKC', 'P38'), ('PKC', 'Mek'), ('PKA', 'P38'), ('PKA', 'Mek'), ('PKA', 'Akt')]
# Score obtido: -72681.54274387838
# Ordem gerada com a feature (Raf): ['Raf', 'PKA', 'Mek', 'PKC', 'Akt', 'P38', 'Jnk', 'Erk', 'Plcg', 'PIP3', 'PIP2']
# Estrutura gerada: [('Raf', 'PKA'), ('Raf', 'Mek'), ('Raf', 'PKC'), ('PKA', 'Mek'), ('PKA', 'PKC'), ('PKA', 'Akt'), ('PKA', 'P38'), ('PKA', 'Jnk'), ('PKA', 'Erk'), ('Mek', 'PKC'), ('Mek', 'Akt'), ('Mek', 'Erk'), ('PKC', 'P38'), ('PKC', 'Jnk'), ('Akt', 'Erk'), ('Plcg', 'PIP3'), ('Plcg', 'PIP2'), ('PIP3', 'PIP2')]
# Score obtido: -72267.14145255707

# %%
from pgmpy.readwrite import XMLBIFWriter

# Especifique o caminho do arquivo onde deseja salvar o arquivo XMLBIF
file_path = "sachs_pearson.xmlbif"

# Adicione as CPDs ao modelo
for cpd in cpds:
    melhor_model.add_cpds(cpd)

# Escreva o modelo no formato XMLBIF
writer = XMLBIFWriter(melhor_model).write_xmlbif(file_path)

print(f"O arquivo XMLBIF foi gerado com sucesso em: {file_path}")
# Out:
# O arquivo XMLBIF foi gerado com sucesso em: sachs_pearson.xmlbif
