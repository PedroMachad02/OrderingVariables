# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import K2Score, BayesianEstimator

def correlacao_pearson(data, target):
    # Calcula a correlação de Pearson entre a coluna alvo e todas as outras colunas
    correlacoes = data.corr(method='pearson')[target]
    
    # Ordena as colunas com base na correlação em ordem decrescente
    correlacoes_ordenadas = correlacoes.abs().sort_values(ascending=False)
    
    # Reordena o DataFrame de acordo com as correlações ordenadas
    colunas_ordenadas = correlacoes_ordenadas.index
    df_ordenado = data[colunas_ordenadas]
    
    return df_ordenado

def k2(dataset, parents_nmax):
    estimator = K2Score(dataset)
    model = BayesianNetwork()
    nodes = list(dataset.columns)
    model.add_nodes_from(nodes)

    for i in range(1, len(nodes)):
        node = nodes[i]
        previous_nodes = nodes[:i]
        parents = []
        P_old = estimator.local_score(node, parents)
        proceed = True

        while proceed and (len(parents) < parents_nmax):
            candidates = list(set(previous_nodes) - set(parents))
            P_new = P_old

            for candidate in candidates:
                candidate_score = estimator.local_score(node, parents + [candidate])

                if candidate_score > P_new:
                    candidates_best = candidate
                    P_new = candidate_score

            if P_new > P_old:
                P_old = P_new
                parents.append(candidates_best)
                model.add_edge(candidates_best, node)
            else:
                proceed = False

    estrutura = list(model.edges)
    score = estimator.score(model)
    return estrutura, model, score

def tabular_cpd(model, data):
    for column in data.columns:
        data[column] = pd.Categorical(data[column])
    estimator = BayesianEstimator(model, data)
    cpds = [estimator.estimate_cpd(node) for node in model.nodes]
    return cpds

# Variáveis para acompanhar a melhor estrutura, melhor ordem, melhor score e a target_column relacionada
melhor_estrutura = None
melhor_ordem = None
melhor_score = float('-inf')
melhor_target = None

data = pd.read_csv('hepartwo.csv')
# Mapear os valores nominais para números inteiros únicos
data = data.apply(LabelEncoder().fit_transform)
variables = list(data.columns)

print("DataFrame original:")
print(list(data))

for target in variables:
    if target == 'target':
        continue
    # Ordena o DataFrame por correlação
    df_ordenado = correlacao_pearson(data, target)
    variable_target = list(df_ordenado)
    estrutura, model, score = k2(df_ordenado, 4)
    print(f'Ordem gerada com a feature ({target}): {variable_target}')
    print(f'Estrutura gerada: {estrutura}')
    print(f'Score obtido: {score}')

    # Verificar se esta estrutura é a melhor até agora
    if score > melhor_score:
        melhor_estrutura = estrutura
        melhor_ordem = list(df_ordenado)
        melhor_score = score
        melhor_target = target
        melhor_model = model

# Tabular as CPDs para o melhor modelo gerado
cpds = tabular_cpd(melhor_model, df_ordenado)

# Abre o arquivo em modo de escrita
with open("hepartwo_pearson.txt", "w") as arquivo:
    # Escreve os prints no arquivo
    arquivo.write(f'Melhor ordem gerada com a feature ({melhor_target}): {melhor_ordem}\n')
    arquivo.write(f'Estrutura dessa ordem: {melhor_estrutura}\n')
    arquivo.write(f'Score obtido dessa ordem: {melhor_score}\n')
# Out:
# DataFrame original:
# ['alcoholism', 'vh_amn', 'hepatotoxic', 'THepatitis', 'hospital', 'surgery', 'gallstones', 'choledocholithotomy', 'injections', 'transfusion', 'ChHepatitis', 'sex', 'age', 'PBC', 'fibrosis', 'diabetes', 'obesity', 'Steatosis', 'Cirrhosis', 'Hyperbilirubinemia', 'triglycerides', 'RHepatitis', 'fatigue', 'bilirubin', 'itching', 'upper_pain', 'fat', 'pain_ruq', 'pressure_ruq', 'phosphatase', 'skin', 'ama', 'le_cells', 'joints', 'pain', 'proteins', 'edema', 'platelet', 'inr', 'bleeding', 'flatulence', 'alcohol', 'encephalopathy', 'urea', 'ascites', 'hepatomegaly', 'hepatalgia', 'density', 'ESR', 'alt', 'ast', 'amylase', 'ggtp', 'cholesterol', 'hbsag', 'hbsag_anti', 'anorexia', 'nausea', 'spleen', 'consciousness', 'spiders', 'jaundice', 'albumin', 'edge', 'irregular_liver', 'hbc_anti', 'hcv_anti', 'palms', 'hbeag', 'carcinoma']
# Ordem gerada com a feature (alcoholism): ['alcoholism', 'Steatosis', 'THepatitis', 'Cirrhosis', 'carcinoma', 'spleen', 'albumin', 'edge', 'inr', 'fibrosis', 'irregular_liver', 'hbeag', 'encephalopathy', 'le_cells', 'age', 'spiders', 'palms', 'bilirubin', 'surgery', 'ggtp', 'choledocholithotomy', 'hepatomegaly', 'hepatotoxic', 'phosphatase', 'pain_ruq', 'transfusion', 'amylase', 'fat', 'alt', 'pressure_ruq', 'hospital', 'sex', 'itching', 'ChHepatitis', 'edema', 'pain', 'alcohol', 'upper_pain', 'anorexia', 'obesity', 'gallstones', 'flatulence', 'joints', 'platelet', 'Hyperbilirubinemia', 'hbc_anti', 'ama', 'PBC', 'consciousness', 'cholesterol', 'vh_amn', 'proteins', 'density', 'ast', 'hbsag_anti', 'urea', 'ascites', 'fatigue', 'hcv_anti', 'diabetes', 'jaundice', 'hbsag', 'RHepatitis', 'nausea', 'ESR', 'hepatalgia', 'bleeding', 'triglycerides', 'injections', 'skin']
# Estrutura gerada: [('alcoholism', 'Steatosis'), ('alcoholism', 'THepatitis'), ('Steatosis', 'Cirrhosis'), ('Steatosis', 'fibrosis'), ('Steatosis', 'pain_ruq'), ('Steatosis', 'alt'), ('Steatosis', 'obesity'), ('Steatosis', 'cholesterol'), ('Steatosis', 'ast'), ('Steatosis', 'ESR'), ('Steatosis', 'triglycerides'), ('THepatitis', 'spiders'), ('THepatitis', 'hepatomegaly'), ('THepatitis', 'phosphatase'), ('THepatitis', 'alt'), ('THepatitis', 'anorexia'), ('THepatitis', 'ast'), ('THepatitis', 'nausea'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'fibrosis'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'proteins'), ('carcinoma', 'le_cells'), ('carcinoma', 'bilirubin'), ('carcinoma', 'ggtp'), ('inr', 'bleeding'), ('fibrosis', 'phosphatase'), ('fibrosis', 'alt'), ('fibrosis', 'ChHepatitis'), ('hbeag', 'ggtp'), ('hbeag', 'alt'), ('hbeag', 'ChHepatitis'), ('hbeag', 'alcohol'), ('hbeag', 'vh_amn'), ('hbeag', 'ast'), ('hbeag', 'ascites'), ('hbeag', 'fatigue'), ('hbeag', 'skin'), ('encephalopathy', 'consciousness'), ('encephalopathy', 'density'), ('encephalopathy', 'urea'), ('le_cells', 'age'), ('le_cells', 'bilirubin'), ('age', 'ggtp'), ('age', 'hepatomegaly'), ('age', 'Hyperbilirubinemia'), ('age', 'ama'), ('age', 'PBC'), ('bilirubin', 'ggtp'), ('bilirubin', 'choledocholithotomy'), ('bilirubin', 'pressure_ruq'), ('bilirubin', 'sex'), ('bilirubin', 'itching'), ('bilirubin', 'gallstones'), ('bilirubin', 'Hyperbilirubinemia'), ('bilirubin', 'ama'), ('bilirubin', 'PBC'), ('bilirubin', 'jaundice'), ('bilirubin', 'skin'), ('surgery', 'transfusion'), ('surgery', 'hospital'), ('surgery', 'injections'), ('ggtp', 'sex'), ('ggtp', 'ama'), ('choledocholithotomy', 'transfusion'), ('choledocholithotomy', 'amylase'), ('choledocholithotomy', 'fat'), ('choledocholithotomy', 'pressure_ruq'), ('choledocholithotomy', 'hospital'), ('choledocholithotomy', 'gallstones'), ('choledocholithotomy', 'injections'), ('hepatomegaly', 'Hyperbilirubinemia'), ('hepatomegaly', 'hepatalgia'), ('phosphatase', 'ChHepatitis'), ('phosphatase', 'RHepatitis'), ('transfusion', 'hospital'), ('transfusion', 'vh_amn'), ('amylase', 'gallstones'), ('amylase', 'flatulence'), ('alt', 'ChHepatitis'), ('pressure_ruq', 'sex'), ('hospital', 'injections'), ('sex', 'pain'), ('sex', 'joints'), ('sex', 'platelet'), ('sex', 'ama'), ('sex', 'PBC'), ('ChHepatitis', 'cholesterol'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'injections'), ('pain', 'joints'), ('obesity', 'diabetes'), ('platelet', 'bleeding'), ('hbc_anti', 'vh_amn'), ('ama', 'PBC'), ('PBC', 'cholesterol'), ('PBC', 'ESR'), ('vh_amn', 'hbsag_anti'), ('vh_amn', 'hbsag'), ('proteins', 'ascites'), ('hbsag_anti', 'hbsag'), ('fatigue', 'RHepatitis'), ('hcv_anti', 'ESR')]
# Score obtido: -327289.1160519524
# Ordem gerada com a feature (vh_amn): ['vh_amn', 'hbsag', 'ChHepatitis', 'fibrosis', 'hbc_anti', 'hbsag_anti', 'phosphatase', 'Cirrhosis', 'hbeag', 'fatigue', 'jaundice', 'spiders', 'ggtp', 'injections', 'inr', 'ascites', 'joints', 'age', 'skin', 'ast', 'carcinoma', 'edema', 'alcohol', 'ama', 'consciousness', 'spleen', 'RHepatitis', 'nausea', 'le_cells', 'cholesterol', 'hepatalgia', 'amylase', 'hepatotoxic', 'hepatomegaly', 'alt', 'diabetes', 'irregular_liver', 'encephalopathy', 'fat', 'pressure_ruq', 'bleeding', 'itching', 'palms', 'albumin', 'platelet', 'upper_pain', 'pain_ruq', 'anorexia', 'hcv_anti', 'alcoholism', 'ESR', 'Steatosis', 'triglycerides', 'PBC', 'surgery', 'gallstones', 'transfusion', 'flatulence', 'Hyperbilirubinemia', 'choledocholithotomy', 'hospital', 'density', 'urea', 'edge', 'sex', 'bilirubin', 'pain', 'obesity', 'proteins', 'THepatitis']
# Estrutura gerada: [('vh_amn', 'hbsag'), ('vh_amn', 'ChHepatitis'), ('vh_amn', 'hbc_anti'), ('vh_amn', 'hbsag_anti'), ('vh_amn', 'transfusion'), ('hbsag', 'ChHepatitis'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'hbc_anti'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'injections'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'transfusion'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'alcoholism'), ('fibrosis', 'Steatosis'), ('phosphatase', 'Cirrhosis'), ('phosphatase', 'RHepatitis'), ('phosphatase', 'THepatitis'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'alcoholism'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'edge'), ('hbeag', 'fatigue'), ('hbeag', 'ascites'), ('hbeag', 'joints'), ('hbeag', 'skin'), ('hbeag', 'alcohol'), ('hbeag', 'platelet'), ('fatigue', 'RHepatitis'), ('jaundice', 'ggtp'), ('jaundice', 'skin'), ('jaundice', 'itching'), ('jaundice', 'bilirubin'), ('ggtp', 'age'), ('ggtp', 'skin'), ('ggtp', 'carcinoma'), ('ggtp', 'ama'), ('ggtp', 'cholesterol'), ('ggtp', 'ESR'), ('ggtp', 'PBC'), ('injections', 'surgery'), ('injections', 'transfusion'), ('injections', 'choledocholithotomy'), ('injections', 'hospital'), ('inr', 'bleeding'), ('ascites', 'proteins'), ('joints', 'pain'), ('age', 'ama'), ('age', 'hepatomegaly'), ('age', 'Hyperbilirubinemia'), ('age', 'sex'), ('skin', 'ama'), ('skin', 'le_cells'), ('skin', 'cholesterol'), ('skin', 'itching'), ('skin', 'bilirubin'), ('carcinoma', 'ama'), ('ama', 'consciousness'), ('ama', 'le_cells'), ('ama', 'cholesterol'), ('ama', 'encephalopathy'), ('ama', 'pressure_ruq'), ('ama', 'itching'), ('ama', 'platelet'), ('ama', 'ESR'), ('ama', 'PBC'), ('consciousness', 'encephalopathy'), ('consciousness', 'pressure_ruq'), ('RHepatitis', 'anorexia'), ('cholesterol', 'ESR'), ('cholesterol', 'PBC'), ('hepatalgia', 'hepatomegaly'), ('amylase', 'gallstones'), ('amylase', 'flatulence'), ('hepatotoxic', 'THepatitis'), ('hepatomegaly', 'Hyperbilirubinemia'), ('diabetes', 'pressure_ruq'), ('diabetes', 'urea'), ('diabetes', 'obesity'), ('encephalopathy', 'density'), ('encephalopathy', 'urea'), ('encephalopathy', 'obesity'), ('fat', 'gallstones'), ('pressure_ruq', 'gallstones'), ('bleeding', 'platelet'), ('itching', 'bilirubin'), ('hcv_anti', 'ESR'), ('alcoholism', 'Steatosis'), ('alcoholism', 'THepatitis'), ('ESR', 'PBC'), ('Steatosis', 'triglycerides'), ('Steatosis', 'obesity'), ('PBC', 'gallstones'), ('PBC', 'sex'), ('PBC', 'bilirubin'), ('PBC', 'pain'), ('surgery', 'transfusion'), ('surgery', 'hospital'), ('gallstones', 'choledocholithotomy'), ('transfusion', 'hospital'), ('Hyperbilirubinemia', 'sex'), ('choledocholithotomy', 'hospital')]
# Score obtido: -327823.7596290074
# Ordem gerada com a feature (hepatotoxic): ['hepatotoxic', 'Hyperbilirubinemia', 'transfusion', 'injections', 'albumin', 'obesity', 'jaundice', 'hospital', 'hepatalgia', 'pain', 'bilirubin', 'RHepatitis', 'flatulence', 'pressure_ruq', 'edema', 'hbsag_anti', 'pain_ruq', 'surgery', 'THepatitis', 'alcoholism', 'ascites', 'fatigue', 'urea', 'sex', 'amylase', 'le_cells', 'ggtp', 'bleeding', 'PBC', 'density', 'consciousness', 'edge', 'ast', 'platelet', 'triglycerides', 'vh_amn', 'hbeag', 'ESR', 'hepatomegaly', 'palms', 'anorexia', 'fibrosis', 'alcohol', 'fat', 'upper_pain', 'ama', 'hcv_anti', 'spleen', 'joints', 'Steatosis', 'hbsag', 'nausea', 'Cirrhosis', 'skin', 'inr', 'hbc_anti', 'age', 'gallstones', 'alt', 'ChHepatitis', 'encephalopathy', 'choledocholithotomy', 'phosphatase', 'proteins', 'diabetes', 'spiders', 'carcinoma', 'irregular_liver', 'itching', 'cholesterol']
# Estrutura gerada: [('hepatotoxic', 'pressure_ruq'), ('hepatotoxic', 'alcoholism'), ('Hyperbilirubinemia', 'hepatalgia'), ('Hyperbilirubinemia', 'bilirubin'), ('Hyperbilirubinemia', 'pressure_ruq'), ('Hyperbilirubinemia', 'pain_ruq'), ('Hyperbilirubinemia', 'sex'), ('Hyperbilirubinemia', 'ggtp'), ('Hyperbilirubinemia', 'PBC'), ('Hyperbilirubinemia', 'hepatomegaly'), ('Hyperbilirubinemia', 'age'), ('transfusion', 'injections'), ('transfusion', 'hospital'), ('transfusion', 'surgery'), ('injections', 'hospital'), ('injections', 'surgery'), ('injections', 'ChHepatitis'), ('injections', 'choledocholithotomy'), ('albumin', 'palms'), ('obesity', 'diabetes'), ('jaundice', 'bilirubin'), ('hospital', 'surgery'), ('hospital', 'choledocholithotomy'), ('hepatalgia', 'hepatomegaly'), ('pain', 'joints'), ('bilirubin', 'sex'), ('bilirubin', 'le_cells'), ('bilirubin', 'ggtp'), ('bilirubin', 'PBC'), ('bilirubin', 'skin'), ('bilirubin', 'gallstones'), ('bilirubin', 'itching'), ('RHepatitis', 'fatigue'), ('RHepatitis', 'ggtp'), ('RHepatitis', 'ast'), ('RHepatitis', 'anorexia'), ('RHepatitis', 'phosphatase'), ('pressure_ruq', 'sex'), ('pressure_ruq', 'gallstones'), ('edema', 'edge'), ('hbsag_anti', 'vh_amn'), ('hbsag_anti', 'hbsag'), ('THepatitis', 'alcoholism'), ('THepatitis', 'fatigue'), ('THepatitis', 'ast'), ('THepatitis', 'anorexia'), ('THepatitis', 'nausea'), ('THepatitis', 'alt'), ('THepatitis', 'phosphatase'), ('THepatitis', 'spiders'), ('alcoholism', 'edge'), ('alcoholism', 'triglycerides'), ('alcoholism', 'Steatosis'), ('ascites', 'proteins'), ('urea', 'consciousness'), ('urea', 'encephalopathy'), ('sex', 'le_cells'), ('sex', 'ggtp'), ('sex', 'PBC'), ('sex', 'age'), ('amylase', 'gallstones'), ('ggtp', 'PBC'), ('bleeding', 'platelet'), ('bleeding', 'inr'), ('PBC', 'density'), ('PBC', 'consciousness'), ('PBC', 'platelet'), ('PBC', 'ESR'), ('PBC', 'ama'), ('PBC', 'joints'), ('PBC', 'age'), ('PBC', 'gallstones'), ('PBC', 'encephalopathy'), ('PBC', 'carcinoma'), ('PBC', 'cholesterol'), ('density', 'encephalopathy'), ('consciousness', 'alcohol'), ('consciousness', 'encephalopathy'), ('edge', 'palms'), ('edge', 'fibrosis'), ('edge', 'spleen'), ('edge', 'Steatosis'), ('edge', 'Cirrhosis'), ('triglycerides', 'Steatosis'), ('vh_amn', 'fibrosis'), ('vh_amn', 'hbsag'), ('vh_amn', 'hbc_anti'), ('vh_amn', 'ChHepatitis'), ('hbeag', 'skin'), ('hbeag', 'age'), ('palms', 'fibrosis'), ('palms', 'spleen'), ('palms', 'Steatosis'), ('palms', 'Cirrhosis'), ('fibrosis', 'alcohol'), ('fibrosis', 'spleen'), ('fibrosis', 'hbsag'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'alt'), ('fibrosis', 'ChHepatitis'), ('hcv_anti', 'alt'), ('Steatosis', 'Cirrhosis'), ('Steatosis', 'alt'), ('Steatosis', 'cholesterol'), ('hbsag', 'hbc_anti'), ('hbsag', 'ChHepatitis'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'irregular_liver'), ('gallstones', 'choledocholithotomy'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'cholesterol')]
# Score obtido: -327171.2350033682
# Ordem gerada com a feature (THepatitis): ['THepatitis', 'alcoholism', 'phosphatase', 'ggtp', 'nausea', 'ast', 'anorexia', 'hepatomegaly', 'fatigue', 'Cirrhosis', 'Steatosis', 'pressure_ruq', 'inr', 'spiders', 'edema', 'edge', 'ChHepatitis', 'albumin', 'gallstones', 'hepatalgia', 'jaundice', 'amylase', 'carcinoma', 'age', 'platelet', 'obesity', 'hepatotoxic', 'density', 'surgery', 'ama', 'Hyperbilirubinemia', 'choledocholithotomy', 'hbc_anti', 'fibrosis', 'cholesterol', 'hcv_anti', 'irregular_liver', 'diabetes', 'pain_ruq', 'le_cells', 'ESR', 'bleeding', 'flatulence', 'ascites', 'itching', 'bilirubin', 'upper_pain', 'hbsag_anti', 'skin', 'palms', 'encephalopathy', 'alt', 'RHepatitis', 'hbeag', 'consciousness', 'sex', 'hbsag', 'triglycerides', 'alcohol', 'spleen', 'transfusion', 'PBC', 'hospital', 'proteins', 'injections', 'pain', 'urea', 'joints', 'vh_amn', 'fat']
# Estrutura gerada: [('THepatitis', 'alcoholism'), ('THepatitis', 'phosphatase'), ('THepatitis', 'ggtp'), ('THepatitis', 'nausea'), ('THepatitis', 'ast'), ('THepatitis', 'anorexia'), ('THepatitis', 'hepatomegaly'), ('THepatitis', 'fatigue'), ('THepatitis', 'pressure_ruq'), ('THepatitis', 'spiders'), ('THepatitis', 'alt'), ('alcoholism', 'Cirrhosis'), ('alcoholism', 'Steatosis'), ('phosphatase', 'Cirrhosis'), ('phosphatase', 'ChHepatitis'), ('phosphatase', 'RHepatitis'), ('ggtp', 'jaundice'), ('ggtp', 'carcinoma'), ('ggtp', 'age'), ('ggtp', 'ama'), ('ggtp', 'cholesterol'), ('ggtp', 'ESR'), ('ast', 'Steatosis'), ('hepatomegaly', 'hepatalgia'), ('hepatomegaly', 'Hyperbilirubinemia'), ('fatigue', 'RHepatitis'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'ChHepatitis'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'fibrosis'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'spleen'), ('Steatosis', 'ChHepatitis'), ('Steatosis', 'obesity'), ('Steatosis', 'fibrosis'), ('Steatosis', 'cholesterol'), ('Steatosis', 'pain_ruq'), ('Steatosis', 'alt'), ('Steatosis', 'triglycerides'), ('pressure_ruq', 'gallstones'), ('inr', 'bleeding'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'hospital'), ('ChHepatitis', 'injections'), ('ChHepatitis', 'vh_amn'), ('gallstones', 'amylase'), ('gallstones', 'surgery'), ('gallstones', 'choledocholithotomy'), ('gallstones', 'upper_pain'), ('gallstones', 'fat'), ('jaundice', 'ama'), ('jaundice', 'itching'), ('jaundice', 'bilirubin'), ('amylase', 'flatulence'), ('carcinoma', 'ama'), ('age', 'ama'), ('age', 'Hyperbilirubinemia'), ('age', 'sex'), ('platelet', 'bleeding'), ('obesity', 'diabetes'), ('density', 'encephalopathy'), ('surgery', 'transfusion'), ('surgery', 'hospital'), ('surgery', 'injections'), ('ama', 'cholesterol'), ('ama', 'le_cells'), ('ama', 'ESR'), ('ama', 'itching'), ('ama', 'bilirubin'), ('ama', 'encephalopathy'), ('ama', 'sex'), ('ama', 'PBC'), ('Hyperbilirubinemia', 'pain_ruq'), ('Hyperbilirubinemia', 'bilirubin'), ('choledocholithotomy', 'transfusion'), ('choledocholithotomy', 'hospital'), ('choledocholithotomy', 'injections'), ('hbc_anti', 'vh_amn'), ('cholesterol', 'le_cells'), ('cholesterol', 'ESR'), ('cholesterol', 'sex'), ('hcv_anti', 'ESR'), ('hcv_anti', 'encephalopathy'), ('hcv_anti', 'alt'), ('diabetes', 'urea'), ('ESR', 'sex'), ('ESR', 'PBC'), ('ascites', 'proteins'), ('itching', 'bilirubin'), ('bilirubin', 'skin'), ('bilirubin', 'PBC'), ('hbsag_anti', 'hbsag'), ('hbsag_anti', 'vh_amn'), ('encephalopathy', 'consciousness'), ('encephalopathy', 'urea'), ('hbeag', 'alcohol'), ('sex', 'PBC'), ('hbsag', 'vh_amn'), ('transfusion', 'hospital'), ('PBC', 'pain'), ('PBC', 'joints'), ('hospital', 'injections'), ('pain', 'joints')]
# Score obtido: -328281.9217470817
# Ordem gerada com a feature (hospital): ['hospital', 'injections', 'transfusion', 'ChHepatitis', 'fibrosis', 'jaundice', 'hbsag', 'phosphatase', 'obesity', 'carcinoma', 'bleeding', 'Cirrhosis', 'ascites', 'hepatotoxic', 'inr', 'triglycerides', 'urea', 'Steatosis', 'albumin', 'hbc_anti', 'palms', 'upper_pain', 'alt', 'ggtp', 'pain_ruq', 'amylase', 'diabetes', 'hcv_anti', 'sex', 'alcoholism', 'ESR', 'choledocholithotomy', 'surgery', 'edema', 'ama', 'fatigue', 'flatulence', 'edge', 'PBC', 'spiders', 'ast', 'pain', 'spleen', 'proteins', 'platelet', 'skin', 'hepatalgia', 'pressure_ruq', 'density', 'itching', 'gallstones', 'anorexia', 'Hyperbilirubinemia', 'irregular_liver', 'alcohol', 'cholesterol', 'hepatomegaly', 'RHepatitis', 'joints', 'THepatitis', 'bilirubin', 'le_cells', 'encephalopathy', 'consciousness', 'hbsag_anti', 'vh_amn', 'fat', 'hbeag', 'nausea', 'age']
# Estrutura gerada: [('hospital', 'injections'), ('hospital', 'transfusion'), ('hospital', 'jaundice'), ('hospital', 'choledocholithotomy'), ('hospital', 'surgery'), ('injections', 'transfusion'), ('injections', 'ChHepatitis'), ('injections', 'choledocholithotomy'), ('injections', 'surgery'), ('transfusion', 'ChHepatitis'), ('transfusion', 'choledocholithotomy'), ('transfusion', 'surgery'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'cholesterol'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'hbeag'), ('fibrosis', 'carcinoma'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'triglycerides'), ('fibrosis', 'Steatosis'), ('jaundice', 'carcinoma'), ('jaundice', 'sex'), ('jaundice', 'skin'), ('jaundice', 'itching'), ('jaundice', 'bilirubin'), ('hbsag', 'vh_amn'), ('phosphatase', 'Cirrhosis'), ('phosphatase', 'RHepatitis'), ('phosphatase', 'THepatitis'), ('obesity', 'Steatosis'), ('obesity', 'diabetes'), ('obesity', 'alcoholism'), ('carcinoma', 'Cirrhosis'), ('carcinoma', 'ggtp'), ('carcinoma', 'sex'), ('carcinoma', 'ama'), ('bleeding', 'inr'), ('bleeding', 'platelet'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'triglycerides'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'skin'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'alcohol'), ('ascites', 'proteins'), ('hepatotoxic', 'THepatitis'), ('triglycerides', 'Steatosis'), ('urea', 'encephalopathy'), ('Steatosis', 'alt'), ('Steatosis', 'ggtp'), ('Steatosis', 'pain_ruq'), ('Steatosis', 'alcoholism'), ('Steatosis', 'ast'), ('Steatosis', 'cholesterol'), ('hbc_anti', 'vh_amn'), ('ggtp', 'sex'), ('ggtp', 'ESR'), ('ggtp', 'ama'), ('ggtp', 'PBC'), ('ggtp', 'Hyperbilirubinemia'), ('amylase', 'choledocholithotomy'), ('amylase', 'flatulence'), ('amylase', 'gallstones'), ('hcv_anti', 'sex'), ('hcv_anti', 'ESR'), ('hcv_anti', 'platelet'), ('hcv_anti', 'pressure_ruq'), ('sex', 'ESR'), ('sex', 'ama'), ('sex', 'PBC'), ('sex', 'age'), ('alcoholism', 'THepatitis'), ('ESR', 'ama'), ('ESR', 'PBC'), ('choledocholithotomy', 'surgery'), ('choledocholithotomy', 'pressure_ruq'), ('choledocholithotomy', 'gallstones'), ('ama', 'PBC'), ('fatigue', 'RHepatitis'), ('PBC', 'pain'), ('PBC', 'platelet'), ('PBC', 'skin'), ('PBC', 'pressure_ruq'), ('PBC', 'density'), ('PBC', 'itching'), ('PBC', 'Hyperbilirubinemia'), ('PBC', 'cholesterol'), ('PBC', 'joints'), ('PBC', 'bilirubin'), ('PBC', 'le_cells'), ('PBC', 'encephalopathy'), ('PBC', 'age'), ('pain', 'joints'), ('skin', 'itching'), ('skin', 'Hyperbilirubinemia'), ('skin', 'bilirubin'), ('hepatalgia', 'hepatomegaly'), ('density', 'encephalopathy'), ('itching', 'bilirubin'), ('gallstones', 'fat'), ('Hyperbilirubinemia', 'hepatomegaly'), ('Hyperbilirubinemia', 'age'), ('THepatitis', 'nausea'), ('encephalopathy', 'consciousness'), ('hbsag_anti', 'vh_amn'), ('hbeag', 'age')]
# Score obtido: -326861.3145969625
# Ordem gerada com a feature (surgery): ['surgery', 'transfusion', 'injections', 'gallstones', 'pain_ruq', 'ggtp', 'PBC', 'ESR', 'sex', 'inr', 'alcoholism', 'ChHepatitis', 'encephalopathy', 'choledocholithotomy', 'hbeag', 'anorexia', 'hepatotoxic', 'Cirrhosis', 'spleen', 'jaundice', 'THepatitis', 'alcohol', 'pain', 'carcinoma', 'amylase', 'hepatomegaly', 'fatigue', 'density', 'fibrosis', 'hbc_anti', 'obesity', 'pressure_ruq', 'skin', 'bilirubin', 'hospital', 'RHepatitis', 'flatulence', 'alt', 'edema', 'Steatosis', 'hbsag_anti', 'palms', 'ama', 'cholesterol', 'hbsag', 'diabetes', 'age', 'itching', 'triglycerides', 'Hyperbilirubinemia', 'ascites', 'bleeding', 'platelet', 'urea', 'proteins', 'vh_amn', 'ast', 'fat', 'joints', 'nausea', 'hepatalgia', 'spiders', 'albumin', 'upper_pain', 'le_cells', 'phosphatase', 'edge', 'hcv_anti', 'consciousness', 'irregular_liver']
# Estrutura gerada: [('surgery', 'transfusion'), ('surgery', 'injections'), ('surgery', 'hospital'), ('transfusion', 'injections'), ('transfusion', 'gallstones'), ('transfusion', 'ChHepatitis'), ('transfusion', 'hospital'), ('injections', 'gallstones'), ('injections', 'ChHepatitis'), ('injections', 'choledocholithotomy'), ('injections', 'hospital'), ('gallstones', 'choledocholithotomy'), ('gallstones', 'amylase'), ('gallstones', 'pressure_ruq'), ('gallstones', 'skin'), ('gallstones', 'bilirubin'), ('gallstones', 'fat'), ('gallstones', 'upper_pain'), ('ggtp', 'PBC'), ('PBC', 'ESR'), ('PBC', 'sex'), ('PBC', 'encephalopathy'), ('PBC', 'jaundice'), ('PBC', 'pain'), ('PBC', 'carcinoma'), ('PBC', 'pressure_ruq'), ('PBC', 'skin'), ('PBC', 'bilirubin'), ('PBC', 'ama'), ('PBC', 'cholesterol'), ('PBC', 'age'), ('PBC', 'Hyperbilirubinemia'), ('PBC', 'platelet'), ('PBC', 'joints'), ('PBC', 'le_cells'), ('sex', 'age'), ('inr', 'ChHepatitis'), ('inr', 'Cirrhosis'), ('inr', 'bleeding'), ('alcoholism', 'Cirrhosis'), ('alcoholism', 'THepatitis'), ('alcoholism', 'Steatosis'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'Cirrhosis'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'cholesterol'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'phosphatase'), ('encephalopathy', 'density'), ('encephalopathy', 'urea'), ('encephalopathy', 'consciousness'), ('choledocholithotomy', 'hospital'), ('hbeag', 'alcohol'), ('hbeag', 'fatigue'), ('hbeag', 'alt'), ('hbeag', 'ascites'), ('hbeag', 'platelet'), ('anorexia', 'RHepatitis'), ('hepatotoxic', 'THepatitis'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'fibrosis'), ('Cirrhosis', 'obesity'), ('Cirrhosis', 'skin'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'irregular_liver'), ('jaundice', 'skin'), ('jaundice', 'bilirubin'), ('THepatitis', 'hepatomegaly'), ('THepatitis', 'alt'), ('THepatitis', 'ast'), ('THepatitis', 'nausea'), ('THepatitis', 'spiders'), ('THepatitis', 'phosphatase'), ('pain', 'joints'), ('amylase', 'flatulence'), ('hepatomegaly', 'Hyperbilirubinemia'), ('hepatomegaly', 'hepatalgia'), ('fatigue', 'RHepatitis'), ('fibrosis', 'Steatosis'), ('hbc_anti', 'vh_amn'), ('obesity', 'Steatosis'), ('obesity', 'diabetes'), ('skin', 'bilirubin'), ('bilirubin', 'itching'), ('bilirubin', 'Hyperbilirubinemia'), ('RHepatitis', 'alt'), ('RHepatitis', 'ast'), ('RHepatitis', 'phosphatase'), ('Steatosis', 'cholesterol'), ('Steatosis', 'triglycerides'), ('Steatosis', 'ast'), ('hbsag_anti', 'hbsag'), ('hbsag_anti', 'vh_amn'), ('hbsag', 'vh_amn'), ('diabetes', 'urea'), ('age', 'Hyperbilirubinemia'), ('ascites', 'proteins'), ('bleeding', 'platelet')]
# Score obtido: -326292.21385602804
# Ordem gerada com a feature (gallstones): ['gallstones', 'choledocholithotomy', 'fat', 'pressure_ruq', 'injections', 'upper_pain', 'amylase', 'surgery', 'alcohol', 'density', 'RHepatitis', 'albumin', 'flatulence', 'skin', 'itching', 'encephalopathy', 'ChHepatitis', 'bilirubin', 'jaundice', 'hepatalgia', 'THepatitis', 'nausea', 'hbsag_anti', 'ast', 'le_cells', 'spleen', 'fatigue', 'hbc_anti', 'edema', 'phosphatase', 'fibrosis', 'Cirrhosis', 'ESR', 'hbsag', 'platelet', 'pain', 'age', 'consciousness', 'edge', 'triglycerides', 'spiders', 'inr', 'irregular_liver', 'carcinoma', 'alcoholism', 'joints', 'ama', 'urea', 'anorexia', 'alt', 'diabetes', 'sex', 'hospital', 'PBC', 'pain_ruq', 'proteins', 'ascites', 'hepatomegaly', 'hbeag', 'cholesterol', 'vh_amn', 'hepatotoxic', 'Steatosis', 'palms', 'obesity', 'ggtp', 'Hyperbilirubinemia', 'bleeding', 'hcv_anti', 'transfusion']
# Estrutura gerada: [('gallstones', 'choledocholithotomy'), ('gallstones', 'fat'), ('gallstones', 'pressure_ruq'), ('gallstones', 'upper_pain'), ('gallstones', 'amylase'), ('gallstones', 'bilirubin'), ('choledocholithotomy', 'injections'), ('choledocholithotomy', 'hospital'), ('choledocholithotomy', 'transfusion'), ('pressure_ruq', 'diabetes'), ('injections', 'surgery'), ('injections', 'ChHepatitis'), ('injections', 'hospital'), ('amylase', 'flatulence'), ('surgery', 'hospital'), ('surgery', 'transfusion'), ('density', 'encephalopathy'), ('RHepatitis', 'ast'), ('RHepatitis', 'fatigue'), ('RHepatitis', 'phosphatase'), ('RHepatitis', 'anorexia'), ('RHepatitis', 'alt'), ('albumin', 'Cirrhosis'), ('skin', 'itching'), ('skin', 'bilirubin'), ('itching', 'bilirubin'), ('encephalopathy', 'consciousness'), ('encephalopathy', 'urea'), ('encephalopathy', 'obesity'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'spleen'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'cholesterol'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'ggtp'), ('bilirubin', 'jaundice'), ('bilirubin', 'le_cells'), ('bilirubin', 'ESR'), ('bilirubin', 'carcinoma'), ('bilirubin', 'joints'), ('bilirubin', 'ama'), ('bilirubin', 'sex'), ('bilirubin', 'PBC'), ('bilirubin', 'Hyperbilirubinemia'), ('hepatalgia', 'hepatomegaly'), ('THepatitis', 'nausea'), ('THepatitis', 'ast'), ('THepatitis', 'phosphatase'), ('THepatitis', 'spiders'), ('THepatitis', 'alcoholism'), ('THepatitis', 'anorexia'), ('THepatitis', 'alt'), ('THepatitis', 'ggtp'), ('hbsag_anti', 'hbsag'), ('hbsag_anti', 'vh_amn'), ('le_cells', 'ESR'), ('le_cells', 'platelet'), ('le_cells', 'age'), ('spleen', 'edema'), ('spleen', 'fibrosis'), ('spleen', 'Cirrhosis'), ('hbc_anti', 'vh_amn'), ('edema', 'Cirrhosis'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'triglycerides'), ('fibrosis', 'alcoholism'), ('fibrosis', 'Steatosis'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'triglycerides'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'alcoholism'), ('Cirrhosis', 'proteins'), ('Cirrhosis', 'cholesterol'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'palms'), ('ESR', 'pain'), ('ESR', 'age'), ('ESR', 'carcinoma'), ('ESR', 'ama'), ('ESR', 'sex'), ('ESR', 'PBC'), ('hbsag', 'vh_amn'), ('platelet', 'bleeding'), ('pain', 'joints'), ('age', 'ama'), ('age', 'sex'), ('age', 'hepatomegaly'), ('age', 'Hyperbilirubinemia'), ('triglycerides', 'Steatosis'), ('inr', 'bleeding'), ('carcinoma', 'ama'), ('alcoholism', 'Steatosis'), ('ama', 'sex'), ('ama', 'PBC'), ('diabetes', 'obesity'), ('sex', 'PBC'), ('hospital', 'transfusion'), ('PBC', 'cholesterol'), ('PBC', 'ggtp'), ('PBC', 'Hyperbilirubinemia'), ('proteins', 'ascites'), ('hepatomegaly', 'Hyperbilirubinemia'), ('hbeag', 'cholesterol'), ('hbeag', 'ggtp'), ('Steatosis', 'obesity')]
# Score obtido: -327607.89245201333
# Ordem gerada com a feature (choledocholithotomy): ['choledocholithotomy', 'gallstones', 'injections', 'fat', 'pressure_ruq', 'ChHepatitis', 'ESR', 'amylase', 'nausea', 'density', 'hepatalgia', 'upper_pain', 'alcohol', 'alcoholism', 'Cirrhosis', 'surgery', 'spleen', 'fibrosis', 'ast', 'le_cells', 'cholesterol', 'fatigue', 'pain_ruq', 'itching', 'encephalopathy', 'RHepatitis', 'phosphatase', 'THepatitis', 'platelet', 'hbc_anti', 'bilirubin', 'PBC', 'anorexia', 'inr', 'hospital', 'pain', 'skin', 'Steatosis', 'irregular_liver', 'flatulence', 'transfusion', 'diabetes', 'Hyperbilirubinemia', 'albumin', 'ama', 'bleeding', 'hbeag', 'obesity', 'spiders', 'triglycerides', 'hcv_anti', 'jaundice', 'proteins', 'ascites', 'edema', 'hbsag', 'hepatotoxic', 'consciousness', 'joints', 'vh_amn', 'urea', 'ggtp', 'alt', 'palms', 'carcinoma', 'sex', 'edge', 'age', 'hbsag_anti', 'hepatomegaly']
# Estrutura gerada: [('choledocholithotomy', 'gallstones'), ('choledocholithotomy', 'injections'), ('choledocholithotomy', 'hospital'), ('choledocholithotomy', 'transfusion'), ('gallstones', 'fat'), ('gallstones', 'pressure_ruq'), ('gallstones', 'amylase'), ('gallstones', 'upper_pain'), ('gallstones', 'bilirubin'), ('injections', 'ChHepatitis'), ('injections', 'surgery'), ('injections', 'hospital'), ('pressure_ruq', 'ESR'), ('pressure_ruq', 'diabetes'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'Cirrhosis'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'ggtp'), ('ChHepatitis', 'alt'), ('ESR', 'le_cells'), ('ESR', 'cholesterol'), ('ESR', 'itching'), ('ESR', 'bilirubin'), ('ESR', 'PBC'), ('amylase', 'flatulence'), ('density', 'encephalopathy'), ('hepatalgia', 'hepatomegaly'), ('alcohol', 'Cirrhosis'), ('alcoholism', 'Cirrhosis'), ('alcoholism', 'THepatitis'), ('alcoholism', 'Steatosis'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'fibrosis'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'PBC'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'proteins'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'edge'), ('surgery', 'hospital'), ('surgery', 'transfusion'), ('fibrosis', 'Steatosis'), ('le_cells', 'cholesterol'), ('le_cells', 'platelet'), ('cholesterol', 'bilirubin'), ('cholesterol', 'PBC'), ('fatigue', 'RHepatitis'), ('pain_ruq', 'Hyperbilirubinemia'), ('itching', 'bilirubin'), ('encephalopathy', 'obesity'), ('encephalopathy', 'consciousness'), ('encephalopathy', 'urea'), ('RHepatitis', 'phosphatase'), ('RHepatitis', 'anorexia'), ('phosphatase', 'THepatitis'), ('THepatitis', 'anorexia'), ('THepatitis', 'spiders'), ('THepatitis', 'alt'), ('platelet', 'bleeding'), ('hbc_anti', 'vh_amn'), ('bilirubin', 'PBC'), ('bilirubin', 'skin'), ('bilirubin', 'Hyperbilirubinemia'), ('bilirubin', 'jaundice'), ('PBC', 'pain'), ('PBC', 'Hyperbilirubinemia'), ('PBC', 'ama'), ('PBC', 'joints'), ('PBC', 'ggtp'), ('PBC', 'carcinoma'), ('PBC', 'sex'), ('PBC', 'age'), ('inr', 'bleeding'), ('hospital', 'transfusion'), ('pain', 'joints'), ('Steatosis', 'obesity'), ('Steatosis', 'triglycerides'), ('Steatosis', 'alt'), ('diabetes', 'obesity'), ('diabetes', 'urea'), ('Hyperbilirubinemia', 'ggtp'), ('Hyperbilirubinemia', 'sex'), ('Hyperbilirubinemia', 'age'), ('Hyperbilirubinemia', 'hepatomegaly'), ('hbeag', 'ascites'), ('hbeag', 'vh_amn'), ('hbeag', 'alt'), ('hbeag', 'age'), ('hcv_anti', 'ggtp'), ('proteins', 'ascites'), ('hbsag', 'vh_amn'), ('vh_amn', 'hbsag_anti'), ('sex', 'age')]
# Score obtido: -326552.8838881251
# Ordem gerada com a feature (injections): ['injections', 'hospital', 'surgery', 'ChHepatitis', 'transfusion', 'choledocholithotomy', 'gallstones', 'fibrosis', 'hbsag', 'phosphatase', 'obesity', 'flatulence', 'hepatotoxic', 'carcinoma', 'hbc_anti', 'Cirrhosis', 'amylase', 'palms', 'hbeag', 'ascites', 'spiders', 'jaundice', 'vh_amn', 'sex', 'edge', 'triglycerides', 'hbsag_anti', 'hcv_anti', 'inr', 'fat', 'diabetes', 'ast', 'density', 'edema', 'consciousness', 'alt', 'albumin', 'joints', 'irregular_liver', 'ggtp', 'platelet', 'hepatalgia', 'nausea', 'fatigue', 'bleeding', 'pain', 'hepatomegaly', 'cholesterol', 'Hyperbilirubinemia', 'le_cells', 'alcohol', 'proteins', 'ama', 'RHepatitis', 'skin', 'pain_ruq', 'age', 'ESR', 'anorexia', 'bilirubin', 'urea', 'spleen', 'upper_pain', 'encephalopathy', 'pressure_ruq', 'THepatitis', 'Steatosis', 'PBC', 'alcoholism', 'itching']
# Estrutura gerada: [('injections', 'hospital'), ('injections', 'surgery'), ('injections', 'ChHepatitis'), ('injections', 'choledocholithotomy'), ('hospital', 'surgery'), ('hospital', 'transfusion'), ('hospital', 'choledocholithotomy'), ('surgery', 'transfusion'), ('surgery', 'choledocholithotomy'), ('ChHepatitis', 'transfusion'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'ESR'), ('transfusion', 'choledocholithotomy'), ('choledocholithotomy', 'gallstones'), ('gallstones', 'amylase'), ('gallstones', 'fat'), ('gallstones', 'upper_pain'), ('gallstones', 'pressure_ruq'), ('fibrosis', 'carcinoma'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'triglycerides'), ('fibrosis', 'Steatosis'), ('hbsag', 'vh_amn'), ('phosphatase', 'Cirrhosis'), ('phosphatase', 'RHepatitis'), ('phosphatase', 'THepatitis'), ('obesity', 'diabetes'), ('obesity', 'Steatosis'), ('hepatotoxic', 'alcoholism'), ('carcinoma', 'Cirrhosis'), ('carcinoma', 'jaundice'), ('carcinoma', 'sex'), ('carcinoma', 'ggtp'), ('carcinoma', 'cholesterol'), ('hbc_anti', 'vh_amn'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'sex'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'triglycerides'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'Steatosis'), ('hbeag', 'ascites'), ('hbeag', 'vh_amn'), ('hbeag', 'joints'), ('hbeag', 'fatigue'), ('hbeag', 'cholesterol'), ('hbeag', 'alcohol'), ('hbeag', 'alcoholism'), ('ascites', 'proteins'), ('jaundice', 'sex'), ('jaundice', 'ama'), ('jaundice', 'skin'), ('jaundice', 'bilirubin'), ('vh_amn', 'hbsag_anti'), ('sex', 'ggtp'), ('sex', 'platelet'), ('sex', 'pain'), ('sex', 'cholesterol'), ('sex', 'Hyperbilirubinemia'), ('sex', 'le_cells'), ('sex', 'ama'), ('sex', 'skin'), ('sex', 'age'), ('sex', 'ESR'), ('sex', 'pressure_ruq'), ('sex', 'PBC'), ('triglycerides', 'Steatosis'), ('hcv_anti', 'anorexia'), ('inr', 'bleeding'), ('diabetes', 'pressure_ruq'), ('ast', 'THepatitis'), ('density', 'consciousness'), ('density', 'encephalopathy'), ('consciousness', 'pain_ruq'), ('consciousness', 'urea'), ('consciousness', 'encephalopathy'), ('joints', 'pain'), ('ggtp', 'cholesterol'), ('ggtp', 'Hyperbilirubinemia'), ('ggtp', 'ama'), ('platelet', 'bleeding'), ('hepatalgia', 'hepatomegaly'), ('fatigue', 'RHepatitis'), ('hepatomegaly', 'Hyperbilirubinemia'), ('cholesterol', 'le_cells'), ('cholesterol', 'ama'), ('cholesterol', 'ESR'), ('Hyperbilirubinemia', 'skin'), ('Hyperbilirubinemia', 'pain_ruq'), ('Hyperbilirubinemia', 'age'), ('Hyperbilirubinemia', 'bilirubin'), ('ama', 'skin'), ('ama', 'age'), ('ama', 'ESR'), ('ama', 'bilirubin'), ('ama', 'pressure_ruq'), ('ama', 'PBC'), ('RHepatitis', 'anorexia'), ('skin', 'bilirubin'), ('ESR', 'PBC'), ('bilirubin', 'PBC'), ('bilirubin', 'itching'), ('urea', 'encephalopathy'), ('THepatitis', 'alcoholism'), ('Steatosis', 'alcoholism')]
# Score obtido: -328278.4942787691
# Ordem gerada com a feature (transfusion): ['transfusion', 'surgery', 'injections', 'hospital', 'ChHepatitis', 'hbsag', 'pain_ruq', 'hepatotoxic', 'ESR', 'pressure_ruq', 'jaundice', 'ast', 'inr', 'upper_pain', 'triglycerides', 'fibrosis', 'edema', 'pain', 'hepatomegaly', 'hbeag', 'Cirrhosis', 'le_cells', 'phosphatase', 'irregular_liver', 'obesity', 'edge', 'alcoholism', 'hepatalgia', 'fatigue', 'proteins', 'itching', 'alt', 'carcinoma', 'PBC', 'consciousness', 'palms', 'platelet', 'alcohol', 'choledocholithotomy', 'encephalopathy', 'RHepatitis', 'anorexia', 'spleen', 'albumin', 'bleeding', 'Hyperbilirubinemia', 'flatulence', 'sex', 'diabetes', 'joints', 'skin', 'Steatosis', 'urea', 'THepatitis', 'nausea', 'density', 'bilirubin', 'vh_amn', 'hbsag_anti', 'ascites', 'age', 'amylase', 'hbc_anti', 'spiders', 'hcv_anti', 'fat', 'cholesterol', 'gallstones', 'ggtp', 'ama']
# Estrutura gerada: [('transfusion', 'surgery'), ('transfusion', 'injections'), ('transfusion', 'hospital'), ('transfusion', 'ChHepatitis'), ('transfusion', 'choledocholithotomy'), ('transfusion', 'vh_amn'), ('surgery', 'injections'), ('surgery', 'hospital'), ('surgery', 'choledocholithotomy'), ('injections', 'hospital'), ('injections', 'ChHepatitis'), ('injections', 'choledocholithotomy'), ('hospital', 'choledocholithotomy'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'hbc_anti'), ('ChHepatitis', 'cholesterol'), ('ChHepatitis', 'ggtp'), ('hbsag', 'vh_amn'), ('pain_ruq', 'Hyperbilirubinemia'), ('hepatotoxic', 'THepatitis'), ('ESR', 'pressure_ruq'), ('ESR', 'jaundice'), ('ESR', 'pain'), ('ESR', 'le_cells'), ('ESR', 'itching'), ('ESR', 'carcinoma'), ('ESR', 'PBC'), ('jaundice', 'itching'), ('jaundice', 'PBC'), ('jaundice', 'skin'), ('jaundice', 'bilirubin'), ('inr', 'Cirrhosis'), ('inr', 'bleeding'), ('triglycerides', 'Cirrhosis'), ('triglycerides', 'Steatosis'), ('fibrosis', 'edema'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'alcoholism'), ('fibrosis', 'Steatosis'), ('edema', 'Cirrhosis'), ('pain', 'joints'), ('hepatomegaly', 'hepatalgia'), ('hepatomegaly', 'Hyperbilirubinemia'), ('hbeag', 'fatigue'), ('hbeag', 'alcohol'), ('hbeag', 'vh_amn'), ('hbeag', 'ascites'), ('hbeag', 'age'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'obesity'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'alcoholism'), ('Cirrhosis', 'proteins'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'spiders'), ('le_cells', 'PBC'), ('phosphatase', 'RHepatitis'), ('phosphatase', 'THepatitis'), ('obesity', 'diabetes'), ('alcoholism', 'Steatosis'), ('alcoholism', 'THepatitis'), ('fatigue', 'RHepatitis'), ('proteins', 'ascites'), ('itching', 'skin'), ('itching', 'bilirubin'), ('carcinoma', 'PBC'), ('PBC', 'consciousness'), ('PBC', 'platelet'), ('PBC', 'encephalopathy'), ('PBC', 'Hyperbilirubinemia'), ('PBC', 'sex'), ('PBC', 'joints'), ('PBC', 'skin'), ('PBC', 'bilirubin'), ('PBC', 'age'), ('PBC', 'cholesterol'), ('PBC', 'ggtp'), ('PBC', 'ama'), ('consciousness', 'encephalopathy'), ('platelet', 'bleeding'), ('choledocholithotomy', 'amylase'), ('choledocholithotomy', 'fat'), ('choledocholithotomy', 'gallstones'), ('encephalopathy', 'urea'), ('encephalopathy', 'density'), ('RHepatitis', 'anorexia'), ('Hyperbilirubinemia', 'sex'), ('Hyperbilirubinemia', 'skin'), ('Hyperbilirubinemia', 'age'), ('Hyperbilirubinemia', 'ggtp'), ('sex', 'age'), ('diabetes', 'urea'), ('skin', 'bilirubin'), ('Steatosis', 'cholesterol'), ('THepatitis', 'nausea'), ('THepatitis', 'spiders'), ('bilirubin', 'gallstones'), ('vh_amn', 'hbsag_anti'), ('vh_amn', 'hbc_anti'), ('amylase', 'gallstones'), ('hcv_anti', 'ggtp')]
# Score obtido: -326709.9114301996
# Ordem gerada com a feature (ChHepatitis): ['ChHepatitis', 'fibrosis', 'hbsag', 'vh_amn', 'phosphatase', 'injections', 'Cirrhosis', 'hbeag', 'hospital', 'irregular_liver', 'ast', 'transfusion', 'alt', 'carcinoma', 'spleen', 'hbc_anti', 'spiders', 'palms', 'edge', 'ESR', 'choledocholithotomy', 'albumin', 'skin', 'cholesterol', 'edema', 'alcohol', 'THepatitis', 'gallstones', 'bilirubin', 'surgery', 'anorexia', 'diabetes', 'density', 'platelet', 'triglycerides', 'ascites', 'upper_pain', 'fatigue', 'pain_ruq', 'sex', 'fat', 'Steatosis', 'urea', 'alcoholism', 'proteins', 'obesity', 'consciousness', 'pain', 'hepatalgia', 'amylase', 'RHepatitis', 'Hyperbilirubinemia', 'inr', 'age', 'encephalopathy', 'ama', 'ggtp', 'hbsag_anti', 'hcv_anti', 'flatulence', 'joints', 'PBC', 'pressure_ruq', 'nausea', 'hepatotoxic', 'hepatomegaly', 'itching', 'jaundice', 'bleeding', 'le_cells']
# Estrutura gerada: [('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'injections'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'transfusion'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'hbc_anti'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'inr'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'triglycerides'), ('fibrosis', 'Steatosis'), ('hbsag', 'vh_amn'), ('vh_amn', 'transfusion'), ('vh_amn', 'hbc_anti'), ('vh_amn', 'hbsag_anti'), ('phosphatase', 'Cirrhosis'), ('phosphatase', 'THepatitis'), ('phosphatase', 'RHepatitis'), ('injections', 'hospital'), ('injections', 'transfusion'), ('injections', 'choledocholithotomy'), ('injections', 'surgery'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'triglycerides'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'inr'), ('hbeag', 'skin'), ('hbeag', 'alcohol'), ('hbeag', 'ascites'), ('hbeag', 'fatigue'), ('hbeag', 'alcoholism'), ('hbeag', 'age'), ('hospital', 'choledocholithotomy'), ('hospital', 'surgery'), ('ast', 'THepatitis'), ('transfusion', 'choledocholithotomy'), ('transfusion', 'surgery'), ('carcinoma', 'ESR'), ('carcinoma', 'skin'), ('carcinoma', 'cholesterol'), ('ESR', 'skin'), ('ESR', 'cholesterol'), ('ESR', 'bilirubin'), ('ESR', 'sex'), ('ESR', 'age'), ('ESR', 'ama'), ('ESR', 'ggtp'), ('ESR', 'PBC'), ('choledocholithotomy', 'gallstones'), ('choledocholithotomy', 'surgery'), ('skin', 'cholesterol'), ('skin', 'bilirubin'), ('cholesterol', 'platelet'), ('cholesterol', 'sex'), ('cholesterol', 'ama'), ('THepatitis', 'anorexia'), ('THepatitis', 'alcoholism'), ('THepatitis', 'nausea'), ('gallstones', 'bilirubin'), ('gallstones', 'upper_pain'), ('gallstones', 'fat'), ('gallstones', 'amylase'), ('gallstones', 'pressure_ruq'), ('bilirubin', 'sex'), ('bilirubin', 'Hyperbilirubinemia'), ('bilirubin', 'ama'), ('bilirubin', 'PBC'), ('bilirubin', 'itching'), ('bilirubin', 'jaundice'), ('diabetes', 'urea'), ('diabetes', 'obesity'), ('density', 'consciousness'), ('density', 'encephalopathy'), ('platelet', 'bleeding'), ('triglycerides', 'Steatosis'), ('ascites', 'proteins'), ('fatigue', 'RHepatitis'), ('pain_ruq', 'Hyperbilirubinemia'), ('sex', 'pain'), ('sex', 'Hyperbilirubinemia'), ('sex', 'age'), ('sex', 'ama'), ('sex', 'ggtp'), ('sex', 'PBC'), ('Steatosis', 'alcoholism'), ('Steatosis', 'obesity'), ('urea', 'consciousness'), ('urea', 'encephalopathy'), ('consciousness', 'encephalopathy'), ('pain', 'joints'), ('hepatalgia', 'hepatomegaly'), ('amylase', 'flatulence'), ('Hyperbilirubinemia', 'age'), ('Hyperbilirubinemia', 'ggtp'), ('Hyperbilirubinemia', 'hepatomegaly'), ('inr', 'bleeding'), ('ama', 'ggtp'), ('ama', 'joints'), ('ama', 'PBC'), ('hcv_anti', 'pressure_ruq'), ('PBC', 'pressure_ruq'), ('PBC', 'le_cells')]
# Score obtido: -327914.1929635166
# Ordem gerada com a feature (sex): ['sex', 'PBC', 'ama', 'cholesterol', 'ESR', 'skin', 'ggtp', 'Hyperbilirubinemia', 'carcinoma', 'pressure_ruq', 'le_cells', 'jaundice', 'bilirubin', 'itching', 'pain', 'encephalopathy', 'platelet', 'hepatomegaly', 'upper_pain', 'consciousness', 'surgery', 'Steatosis', 'joints', 'hbc_anti', 'hcv_anti', 'injections', 'proteins', 'hepatalgia', 'pain_ruq', 'spleen', 'fat', 'hbeag', 'nausea', 'urea', 'ChHepatitis', 'hepatotoxic', 'albumin', 'obesity', 'hospital', 'bleeding', 'alcoholism', 'phosphatase', 'fibrosis', 'alt', 'triglycerides', 'inr', 'age', 'hbsag', 'Cirrhosis', 'amylase', 'gallstones', 'RHepatitis', 'ast', 'THepatitis', 'transfusion', 'diabetes', 'flatulence', 'spiders', 'fatigue', 'ascites', 'palms', 'anorexia', 'hbsag_anti', 'irregular_liver', 'edema', 'vh_amn', 'choledocholithotomy', 'alcohol', 'density', 'edge']
# ...
# Estrutura gerada: [('hcv_anti', 'encephalopathy'), ('hcv_anti', 'obesity'), ('hcv_anti', 'Hyperbilirubinemia'), ('hcv_anti', 'Steatosis'), ('hcv_anti', 'pressure_ruq'), ('hcv_anti', 'ESR'), ('hcv_anti', 'platelet'), ('hcv_anti', 'inr'), ('encephalopathy', 'consciousness'), ('encephalopathy', 'PBC'), ('encephalopathy', 'density'), ('encephalopathy', 'irregular_liver'), ('encephalopathy', 'urea'), ('obesity', 'diabetes'), ('obesity', 'Steatosis'), ('Hyperbilirubinemia', 'PBC'), ('Hyperbilirubinemia', 'sex'), ('Hyperbilirubinemia', 'age'), ('Hyperbilirubinemia', 'itching'), ('Hyperbilirubinemia', 'hepatomegaly'), ('Hyperbilirubinemia', 'bilirubin'), ('Hyperbilirubinemia', 'ggtp'), ('Hyperbilirubinemia', 'pain_ruq'), ('consciousness', 'pressure_ruq'), ('consciousness', 'pain_ruq'), ('PBC', 'ama'), ('PBC', 'sex'), ('PBC', 'age'), ('PBC', 'pressure_ruq'), ('PBC', 'cholesterol'), ('PBC', 'itching'), ('PBC', 'ESR'), ('PBC', 'bilirubin'), ('PBC', 'ggtp'), ('PBC', 'le_cells'), ('PBC', 'platelet'), ('PBC', 'carcinoma'), ('PBC', 'pain'), ('PBC', 'joints'), ('diabetes', 'pressure_ruq'), ('diabetes', 'urea'), ('Steatosis', 'phosphatase'), ('Steatosis', 'alt'), ('Steatosis', 'edema'), ('Steatosis', 'cholesterol'), ('Steatosis', 'spiders'), ('Steatosis', 'hepatomegaly'), ('Steatosis', 'ESR'), ('Steatosis', 'ast'), ('Steatosis', 'ggtp'), ('Steatosis', 'pain_ruq'), ('Steatosis', 'irregular_liver'), ('Steatosis', 'spleen'), ('Steatosis', 'Cirrhosis'), ('Steatosis', 'alcoholism'), ('Steatosis', 'triglycerides'), ('sex', 'age'), ('phosphatase', 'injections'), ('phosphatase', 'THepatitis'), ('phosphatase', 'fibrosis'), ('phosphatase', 'RHepatitis'), ('phosphatase', 'ChHepatitis'), ('edema', 'spiders'), ('bleeding', 'platelet'), ('bleeding', 'inr'), ('injections', 'hospital'), ('injections', 'hbsag'), ('injections', 'choledocholithotomy'), ('injections', 'ChHepatitis'), ('injections', 'transfusion'), ('injections', 'surgery'), ('amylase', 'flatulence'), ('amylase', 'choledocholithotomy'), ('amylase', 'gallstones'), ('spiders', 'fibrosis'), ('spiders', 'irregular_liver'), ('spiders', 'Cirrhosis'), ('fat', 'pain_ruq'), ('fat', 'choledocholithotomy'), ('hospital', 'choledocholithotomy'), ('hospital', 'surgery'), ('itching', 'bilirubin'), ('hepatomegaly', 'hepatalgia'), ('THepatitis', 'nausea'), ('THepatitis', 'ast'), ('THepatitis', 'fatigue'), ('THepatitis', 'ggtp'), ('THepatitis', 'alcoholism'), ('fibrosis', 'ESR'), ('fibrosis', 'hbsag'), ('fibrosis', 'vh_amn'), ('fibrosis', 'irregular_liver'), ('fibrosis', 'platelet'), ('fibrosis', 'ChHepatitis'), ('fibrosis', 'spleen'), ('fibrosis', 'Cirrhosis'), ('bilirubin', 'skin'), ('bilirubin', 'jaundice'), ('bilirubin', 'gallstones'), ('RHepatitis', 'fatigue'), ('hbsag_anti', 'vh_amn'), ('hbc_anti', 'vh_amn'), ('proteins', 'ascites'), ('hbsag', 'vh_amn'), ('hbsag', 'ChHepatitis'), ('hepatotoxic', 'alcoholism'), ('choledocholithotomy', 'gallstones'), ('choledocholithotomy', 'surgery'), ('vh_amn', 'transfusion'), ('irregular_liver', 'spleen'), ('irregular_liver', 'Cirrhosis'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'transfusion'), ('hbeag', 'alcoholism'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'edge'), ('pain', 'joints'), ('transfusion', 'surgery')]
# Score obtido: -326632.46668661153
# Ordem gerada com a feature (palms): ['palms', 'Cirrhosis', 'Steatosis', 'fibrosis', 'edge', 'carcinoma', 'spleen', 'irregular_liver', 'spiders', 'inr', 'albumin', 'ChHepatitis', 'obesity', 'nausea', 'bleeding', 'phosphatase', 'cholesterol', 'ama', 'bilirubin', 'injections', 'alcoholism', 'joints', 'hepatalgia', 'edema', 'alt', 'hbsag', 'hospital', 'itching', 'consciousness', 'ascites', 'platelet', 'urea', 'hbeag', 'PBC', 'density', 'pressure_ruq', 'ESR', 'fat', 'transfusion', 'alcohol', 'hepatotoxic', 'hepatomegaly', 'RHepatitis', 'pain_ruq', 'age', 'surgery', 'flatulence', 'triglycerides', 'THepatitis', 'fatigue', 'vh_amn', 'hbc_anti', 'skin', 'pain', 'Hyperbilirubinemia', 'proteins', 'gallstones', 'hbsag_anti', 'le_cells', 'sex', 'upper_pain', 'ast', 'amylase', 'hcv_anti', 'choledocholithotomy', 'diabetes', 'jaundice', 'anorexia', 'encephalopathy', 'ggtp']
# Estrutura gerada: [('palms', 'Cirrhosis'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'fibrosis'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'carcinoma'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'alcohol'), ('Steatosis', 'fibrosis'), ('Steatosis', 'obesity'), ('Steatosis', 'cholesterol'), ('Steatosis', 'ama'), ('Steatosis', 'alcoholism'), ('Steatosis', 'alt'), ('Steatosis', 'ESR'), ('Steatosis', 'pain_ruq'), ('Steatosis', 'triglycerides'), ('Steatosis', 'ast'), ('fibrosis', 'ChHepatitis'), ('carcinoma', 'cholesterol'), ('carcinoma', 'ama'), ('carcinoma', 'bilirubin'), ('carcinoma', 'PBC'), ('inr', 'ChHepatitis'), ('inr', 'bleeding'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'injections'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'ESR'), ('ChHepatitis', 'transfusion'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'hbc_anti'), ('ChHepatitis', 'gallstones'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'ggtp'), ('obesity', 'alcoholism'), ('obesity', 'diabetes'), ('bleeding', 'platelet'), ('phosphatase', 'RHepatitis'), ('phosphatase', 'THepatitis'), ('cholesterol', 'ama'), ('cholesterol', 'bilirubin'), ('cholesterol', 'PBC'), ('ama', 'bilirubin'), ('ama', 'joints'), ('ama', 'consciousness'), ('ama', 'platelet'), ('ama', 'PBC'), ('bilirubin', 'itching'), ('bilirubin', 'PBC'), ('bilirubin', 'skin'), ('bilirubin', 'Hyperbilirubinemia'), ('bilirubin', 'gallstones'), ('bilirubin', 'jaundice'), ('injections', 'hospital'), ('injections', 'transfusion'), ('injections', 'surgery'), ('injections', 'choledocholithotomy'), ('alcoholism', 'THepatitis'), ('joints', 'pain'), ('hepatalgia', 'hepatomegaly'), ('hbsag', 'transfusion'), ('hbsag', 'vh_amn'), ('hospital', 'surgery'), ('hospital', 'choledocholithotomy'), ('consciousness', 'urea'), ('consciousness', 'density'), ('consciousness', 'pressure_ruq'), ('consciousness', 'encephalopathy'), ('ascites', 'proteins'), ('urea', 'encephalopathy'), ('hbeag', 'alcohol'), ('hbeag', 'fatigue'), ('hbeag', 'vh_amn'), ('hbeag', 'skin'), ('PBC', 'density'), ('PBC', 'pressure_ruq'), ('PBC', 'ESR'), ('PBC', 'age'), ('PBC', 'pain'), ('PBC', 'Hyperbilirubinemia'), ('PBC', 'gallstones'), ('PBC', 'le_cells'), ('PBC', 'sex'), ('PBC', 'encephalopathy'), ('PBC', 'ggtp'), ('density', 'encephalopathy'), ('pressure_ruq', 'gallstones'), ('fat', 'pain_ruq'), ('transfusion', 'surgery'), ('transfusion', 'vh_amn'), ('hepatotoxic', 'THepatitis'), ('hepatomegaly', 'Hyperbilirubinemia'), ('RHepatitis', 'fatigue'), ('RHepatitis', 'ast'), ('RHepatitis', 'anorexia'), ('age', 'Hyperbilirubinemia'), ('age', 'sex'), ('THepatitis', 'ast'), ('THepatitis', 'anorexia'), ('vh_amn', 'hbc_anti'), ('vh_amn', 'hbsag_anti'), ('Hyperbilirubinemia', 'sex'), ('Hyperbilirubinemia', 'ggtp'), ('gallstones', 'upper_pain'), ('gallstones', 'amylase'), ('gallstones', 'choledocholithotomy'), ('hcv_anti', 'anorexia'), ('hcv_anti', 'ggtp')]
# Score obtido: -326414.05121161364
# Ordem gerada com a feature (hbeag): ['hbeag', 'ChHepatitis', 'ascites', 'alcoholism', 'fatigue', 'irregular_liver', 'joints', 'fibrosis', 'alt', 'vh_amn', 'anorexia', 'inr', 'injections', 'ggtp', 'cholesterol', 'amylase', 'ast', 'diabetes', 'le_cells', 'age', 'surgery', 'density', 'transfusion', 'spleen', 'skin', 'hepatomegaly', 'alcohol', 'hepatalgia', 'carcinoma', 'sex', 'encephalopathy', 'consciousness', 'flatulence', 'palms', 'edema', 'Steatosis', 'hbsag_anti', 'Cirrhosis', 'ama', 'albumin', 'platelet', 'hbsag', 'bilirubin', 'hepatotoxic', 'spiders', 'pressure_ruq', 'choledocholithotomy', 'phosphatase', 'proteins', 'Hyperbilirubinemia', 'itching', 'PBC', 'triglycerides', 'jaundice', 'THepatitis', 'pain_ruq', 'hbc_anti', 'obesity', 'hcv_anti', 'gallstones', 'nausea', 'upper_pain', 'edge', 'fat', 'ESR', 'bleeding', 'hospital', 'pain', 'RHepatitis', 'urea']
# Estrutura gerada: [('hbeag', 'ChHepatitis'), ('hbeag', 'ascites'), ('hbeag', 'alcoholism'), ('hbeag', 'fatigue'), ('hbeag', 'joints'), ('hbeag', 'vh_amn'), ('hbeag', 'age'), ('hbeag', 'skin'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'irregular_liver'), ('ChHepatitis', 'fibrosis'), ('ChHepatitis', 'alt'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'inr'), ('ChHepatitis', 'injections'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'transfusion'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'hbc_anti'), ('ChHepatitis', 'ESR'), ('ascites', 'proteins'), ('alcoholism', 'Steatosis'), ('alcoholism', 'THepatitis'), ('fatigue', 'RHepatitis'), ('irregular_liver', 'fibrosis'), ('irregular_liver', 'inr'), ('irregular_liver', 'spleen'), ('irregular_liver', 'carcinoma'), ('irregular_liver', 'palms'), ('irregular_liver', 'Steatosis'), ('irregular_liver', 'Cirrhosis'), ('joints', 'pain'), ('fibrosis', 'spleen'), ('fibrosis', 'alcohol'), ('fibrosis', 'carcinoma'), ('fibrosis', 'palms'), ('fibrosis', 'edema'), ('fibrosis', 'Cirrhosis'), ('fibrosis', 'choledocholithotomy'), ('vh_amn', 'transfusion'), ('vh_amn', 'hbsag_anti'), ('vh_amn', 'hbsag'), ('vh_amn', 'hbc_anti'), ('inr', 'bleeding'), ('injections', 'surgery'), ('injections', 'transfusion'), ('injections', 'choledocholithotomy'), ('injections', 'hospital'), ('ggtp', 'cholesterol'), ('ggtp', 'age'), ('ggtp', 'sex'), ('cholesterol', 'le_cells'), ('cholesterol', 'age'), ('cholesterol', 'skin'), ('cholesterol', 'carcinoma'), ('cholesterol', 'sex'), ('cholesterol', 'ama'), ('cholesterol', 'PBC'), ('amylase', 'age'), ('amylase', 'flatulence'), ('amylase', 'choledocholithotomy'), ('amylase', 'gallstones'), ('diabetes', 'pressure_ruq'), ('diabetes', 'obesity'), ('diabetes', 'urea'), ('le_cells', 'skin'), ('age', 'hepatomegaly'), ('age', 'ama'), ('age', 'Hyperbilirubinemia'), ('surgery', 'transfusion'), ('surgery', 'hospital'), ('density', 'encephalopathy'), ('transfusion', 'hospital'), ('skin', 'sex'), ('skin', 'ama'), ('skin', 'bilirubin'), ('hepatomegaly', 'hepatalgia'), ('hepatomegaly', 'Hyperbilirubinemia'), ('carcinoma', 'palms'), ('carcinoma', 'edema'), ('carcinoma', 'Steatosis'), ('sex', 'ama'), ('sex', 'platelet'), ('sex', 'bilirubin'), ('sex', 'pressure_ruq'), ('sex', 'PBC'), ('encephalopathy', 'consciousness'), ('encephalopathy', 'obesity'), ('encephalopathy', 'urea'), ('consciousness', 'pain_ruq'), ('palms', 'Steatosis'), ('palms', 'Cirrhosis'), ('Steatosis', 'Cirrhosis'), ('Steatosis', 'triglycerides'), ('Steatosis', 'pain_ruq'), ('Steatosis', 'obesity'), ('Steatosis', 'ESR'), ('hbsag_anti', 'hbsag'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'phosphatase'), ('Cirrhosis', 'edge'), ('ama', 'bilirubin'), ('ama', 'pressure_ruq'), ('ama', 'PBC'), ('platelet', 'bleeding'), ('bilirubin', 'choledocholithotomy'), ('bilirubin', 'Hyperbilirubinemia'), ('bilirubin', 'itching'), ('bilirubin', 'PBC'), ('bilirubin', 'jaundice'), ('bilirubin', 'gallstones'), ('hepatotoxic', 'THepatitis'), ('choledocholithotomy', 'gallstones'), ('choledocholithotomy', 'hospital'), ('phosphatase', 'THepatitis'), ('phosphatase', 'RHepatitis'), ('Hyperbilirubinemia', 'pain_ruq'), ('PBC', 'ESR'), ('PBC', 'pain'), ('THepatitis', 'nausea'), ('hcv_anti', 'ESR'), ('gallstones', 'upper_pain'), ('gallstones', 'fat')]
# Score obtido: -328177.16090717743
# Ordem gerada com a feature (carcinoma): ['carcinoma', 'Cirrhosis', 'PBC', 'Steatosis', 'fibrosis', 'ama', 'cholesterol', 'sex', 'irregular_liver', 'spiders', 'ESR', 'spleen', 'palms', 'skin', 'edge', 'alcoholism', 'ggtp', 'inr', 'albumin', 'edema', 'age', 'le_cells', 'ChHepatitis', 'jaundice', 'Hyperbilirubinemia', 'triglycerides', 'pressure_ruq', 'fatigue', 'itching', 'platelet', 'obesity', 'injections', 'bilirubin', 'hospital', 'hbsag_anti', 'hbsag', 'ascites', 'density', 'alcohol', 'RHepatitis', 'hepatomegaly', 'vh_amn', 'pain', 'THepatitis', 'hbeag', 'surgery', 'bleeding', 'nausea', 'joints', 'ast', 'transfusion', 'diabetes', 'proteins', 'hbc_anti', 'consciousness', 'gallstones', 'fat', 'encephalopathy', 'phosphatase', 'urea', 'flatulence', 'hepatalgia', 'alt', 'upper_pain', 'pain_ruq', 'hcv_anti', 'amylase', 'choledocholithotomy', 'anorexia', 'hepatotoxic']
# Estrutura gerada: [('carcinoma', 'Cirrhosis'), ('carcinoma', 'PBC'), ('Cirrhosis', 'PBC'), ('Cirrhosis', 'Steatosis'), ('Cirrhosis', 'fibrosis'), ('Cirrhosis', 'irregular_liver'), ('Cirrhosis', 'spiders'), ('Cirrhosis', 'spleen'), ('Cirrhosis', 'palms'), ('Cirrhosis', 'skin'), ('Cirrhosis', 'edge'), ('Cirrhosis', 'inr'), ('Cirrhosis', 'albumin'), ('Cirrhosis', 'edema'), ('Cirrhosis', 'platelet'), ('Cirrhosis', 'alcohol'), ('Cirrhosis', 'phosphatase'), ('PBC', 'ama'), ('PBC', 'cholesterol'), ('PBC', 'sex'), ('PBC', 'ESR'), ('PBC', 'skin'), ('PBC', 'ggtp'), ('PBC', 'age'), ('PBC', 'le_cells'), ('PBC', 'ChHepatitis'), ('PBC', 'jaundice'), ('PBC', 'pressure_ruq'), ('PBC', 'itching'), ('PBC', 'platelet'), ('PBC', 'bilirubin'), ('PBC', 'density'), ('PBC', 'pain'), ('PBC', 'joints'), ('PBC', 'consciousness'), ('PBC', 'gallstones'), ('PBC', 'encephalopathy'), ('Steatosis', 'fibrosis'), ('Steatosis', 'cholesterol'), ('Steatosis', 'ESR'), ('Steatosis', 'alcoholism'), ('Steatosis', 'ggtp'), ('Steatosis', 'triglycerides'), ('Steatosis', 'obesity'), ('Steatosis', 'hepatomegaly'), ('Steatosis', 'ast'), ('Steatosis', 'alt'), ('Steatosis', 'pain_ruq'), ('fibrosis', 'ESR'), ('fibrosis', 'ChHepatitis'), ('sex', 'age'), ('sex', 'Hyperbilirubinemia'), ('ESR', 'ChHepatitis'), ('skin', 'jaundice'), ('skin', 'itching'), ('skin', 'bilirubin'), ('alcoholism', 'THepatitis'), ('ggtp', 'THepatitis'), ('inr', 'bleeding'), ('age', 'Hyperbilirubinemia'), ('ChHepatitis', 'fatigue'), ('ChHepatitis', 'injections'), ('ChHepatitis', 'hbsag'), ('ChHepatitis', 'vh_amn'), ('ChHepatitis', 'hbeag'), ('ChHepatitis', 'ast'), ('ChHepatitis', 'transfusion'), ('ChHepatitis', 'hbc_anti'), ('ChHepatitis', 'gallstones'), ('ChHepatitis', 'phosphatase'), ('ChHepatitis', 'alt'), ('jaundice', 'itching'), ('jaundice', 'bilirubin'), ('Hyperbilirubinemia', 'hepatomegaly'), ('Hyperbilirubinemia', 'pain_ruq'), ('pressure_ruq', 'gallstones'), ('fatigue', 'RHepatitis'), ('itching', 'bilirubin'), ('platelet', 'bleeding'), ('obesity', 'diabetes'), ('injections', 'hospital'), ('injections', 'surgery'), ('injections', 'choledocholithotomy'), ('bilirubin', 'gallstones'), ('hospital', 'surgery'), ('hospital', 'transfusion'), ('hospital', 'choledocholithotomy'), ('hbsag_anti', 'hbsag'), ('hbsag_anti', 'vh_amn'), ('hbsag', 'vh_amn'), ('ascites', 'proteins'), ('density', 'consciousness'), ('density', 'encephalopathy'), ('RHepatitis', 'ast'), ('RHepatitis', 'phosphatase'), ('RHepatitis', 'anorexia'), ('hepatomegaly', 'hepatalgia'), ('vh_amn', 'hbc_anti'), ('pain', 'joints'), ('THepatitis', 'nausea'), ('THepatitis', 'ast'), ('THepatitis', 'phosphatase'), ('THepatitis', 'alt'), ('THepatitis', 'anorexia'), ('hbeag', 'alt'), ('surgery', 'transfusion'), ('diabetes', 'urea'), ('consciousness', 'encephalopathy'), ('consciousness', 'pain_ruq'), ('gallstones', 'fat'), ('gallstones', 'upper_pain'), ('gallstones', 'amylase'), ('gallstones', 'choledocholithotomy'), ('fat', 'pain_ruq'), ('encephalopathy', 'urea'), ('hcv_anti', 'anorexia')]
# Score obtido: -326220.1690930831

# %%
from pgmpy.readwrite import XMLBIFWriter

# Especifique o caminho do arquivo onde deseja salvar o arquivo XMLBIF
file_path = "hepartwo_pearson.xmlbif"

# Adicione as CPDs ao modelo
for cpd in cpds:
    melhor_model.add_cpds(cpd)

# Escreva o modelo no formato XMLBIF
writer = XMLBIFWriter(melhor_model).write_xmlbif(file_path)

print(f"O arquivo XMLBIF foi gerado com sucesso em: {file_path}")
# Out:
# O arquivo XMLBIF foi gerado com sucesso em: hepartwo_pearson.xmlbif
